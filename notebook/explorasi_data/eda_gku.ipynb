# %% [markdown]
# <a href="https://colab.research.google.com/github/Junaidirah/predictive_pm25/blob/master/notebook/explorasi_data/eda_gku.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import calendar

# %%
# path = "D:\development\predictive_pm25\data\data_training\TUTL_RAW_2023-2025.csv"
data_path_2024 = "/content/gku_valid(2).csv"

# %%
data_path_2025 = "/content/gku_valid(3).csv"

# %%
df_2025 = pd.read_csv(data_path_2024)
df_2024 = pd.read_csv(data_path_2025)

# %%
df_2024.tail(10)
# Out:
#             id           created_at  temperature  humidity  sht31_temp  \
# 243220  498117  2024-12-31 23:40:00         22.6      84.0       21.10
# 243221  498118  2024-12-31 23:42:00         22.7      84.0       21.08
# 243222  498119  2024-12-31 23:44:00         22.6      84.0       21.01
# 243223  498120  2024-12-31 23:46:00         22.6      84.0       21.03
# 243224  498121  2024-12-31 23:48:00         22.6      85.0       21.05
# 243225  498122  2024-12-31 23:50:00         22.6      85.0       21.15
# 243226  498123  2024-12-31 23:52:00         22.6      85.0       21.09
# 243227  498124  2024-12-31 23:54:00         22.6      86.0       21.12
# 243228  498125  2024-12-31 23:56:00         22.6      86.0       21.19
# 243229  498126  2024-12-31 23:58:00         22.5      86.0       21.25
#
#         sht31_hum     co2   pm25    ws     wd  pressure  solar  solar_cast  \
# 243220      100.0  668.28  29.48  0.00  338.0  932.8579    NaN         NaN
# 243221      100.0  666.34  30.15  0.00  338.0  932.8714    NaN         NaN
# 243222      100.0  672.25  29.48  0.00  338.0  932.9144    NaN         NaN
# 243223      100.0     NaN  42.21  0.00  338.0  932.9072    NaN         NaN
# 243224      100.0     NaN  49.58  0.00  338.0  932.9448    NaN         NaN
# 243225      100.0  677.24  42.21  0.00  338.0  932.9406    NaN         NaN
# 243226      100.0  677.25  34.84  0.00  315.0  932.9471    NaN         NaN
# 243227      100.0  682.19  36.18  0.00  315.0  932.8811    NaN         NaN
# 243228      100.0  689.21  35.51  1.52  315.0  932.8645    NaN         NaN
# 243229      100.0  685.24  34.17  0.00  315.0  932.8167    NaN         NaN
#
#         rainfall
# 243220       NaN
# 243221       NaN
# 243222       NaN
# 243223       NaN
# 243224       NaN
# 243225       NaN
# 243226       NaN
# 243227       NaN
# 243228       NaN
# 243229       NaN

# %%
df_2025.tail(10)
# Out:
#             id           created_at  temperature  humidity  sht31_temp  \
# 231916  730043  2025-12-31 23:40:00        23.87      84.0         0.0
# 231917  730044  2025-12-31 23:42:00        23.83      84.0         0.0
# 231918  730045  2025-12-31 23:44:00        23.86      84.0         0.0
# 231919  730046  2025-12-31 23:46:00        23.65      84.0         0.0
# 231920  730047  2025-12-31 23:48:00        23.74      84.0         0.0
# 231921  730048  2025-12-31 23:50:00        23.55      85.0         0.0
# 231922  730049  2025-12-31 23:52:00        23.44      85.0         0.0
# 231923  730050  2025-12-31 23:54:00        23.57      85.0         0.0
# 231924  730051  2025-12-31 23:56:00        23.48      85.0         0.0
# 231925  730052  2025-12-31 23:58:00        23.33      85.0         0.0
#
#         sht31_hum    co2   pm25    ws   wd  pressure  solar  solar_cast  \
# 231916        0.0  873.0  95.81  3.39  0.0       NaN    NaN         NaN
# 231917        0.0  872.0  91.12  3.97  0.0       NaN    NaN         NaN
# 231918        0.0  867.0  90.45  3.13  0.0       NaN    NaN         NaN
# 231919        0.0  866.0  88.44  3.39  0.0       NaN    NaN         NaN
# 231920        0.0  870.0  90.45  3.58  0.0       NaN    NaN         NaN
# 231921        0.0  873.0  90.45  3.42  0.0       NaN    NaN         NaN
# 231922        0.0  865.0  89.11  3.49  0.0       NaN    NaN         NaN
# 231923        0.0  865.0  89.11  3.10  0.0       NaN    NaN         NaN
# 231924        0.0  858.0  87.77  3.26  0.0       NaN    NaN         NaN
# 231925        0.0  858.0  88.44  3.24  0.0       NaN    NaN         NaN
#
#         rainfall
# 231916       NaN
# 231917       NaN
# 231918       NaN
# 231919       NaN
# 231920       NaN
# 231921       NaN
# 231922       NaN
# 231923       NaN
# 231924       NaN
# 231925       NaN

# %%
df = pd.concat([df_2024, df_2025])
df.head(10)
# Out:
#        id           created_at  temperature  humidity  sht31_temp  sht31_hum  \
# 0  254867  2024-01-01 00:00:46         22.0      99.9         NaN       1.84
# 1  254868  2024-01-01 00:02:17         22.0      99.9         NaN       1.84
# 2  254871  2024-01-01 00:06:47         22.0      99.9         NaN       1.84
# 3  254872  2024-01-01 00:08:18         22.0      99.9         NaN       1.84
# 4  254875  2024-01-01 00:12:48         21.9      99.9         NaN       1.83
# 5  254876  2024-01-01 00:14:19         21.9      99.9         NaN       1.83
# 6  254879  2024-01-01 00:18:49         21.8      99.9         NaN       1.83
# 7  254880  2024-01-01 00:20:19         21.8      99.9         NaN       1.83
# 8  254883  2024-01-01 00:24:50         21.7      99.9         NaN       1.83
# 9  254884  2024-01-01 00:26:20         21.7      99.9         NaN       1.83
#
#           co2    pm25  ws  wd  pressure  solar  solar_cast  rainfall
# 0   934.14001  130.65 NaN NaN       NaN    NaN         NaN       NaN
# 1   934.14001  130.65 NaN NaN       NaN    NaN         NaN       NaN
# 2  1147.96997  130.65 NaN NaN       NaN    NaN         NaN       NaN
# 3  1147.96997  130.65 NaN NaN       NaN    NaN         NaN       NaN
# 4  1086.88000  130.65 NaN NaN       NaN    NaN         NaN       NaN
# 5  1086.88000  130.65 NaN NaN       NaN    NaN         NaN       NaN
# 6   964.69000  130.65 NaN NaN       NaN    NaN         NaN       NaN
# 7   964.69000  130.65 NaN NaN       NaN    NaN         NaN       NaN
# 8   918.87000  130.65 NaN NaN       NaN    NaN         NaN       NaN
# 9   918.87000  130.65 NaN NaN       NaN    NaN         NaN       NaN

# %% [markdown]
# ## Data cleaning

# %%
df.describe()
# Out:
#                   id    temperature       humidity     sht31_temp  \
# count  475156.000000  468183.000000  468265.000000  351956.000000
# mean   492471.232061      26.749465      75.872451      24.420967
# std    137170.205982       4.413203      18.968561       6.955914
# min    254867.000000      -6.070000       0.000000      -4.630000
# 25%    373685.750000      23.400000      63.000000      21.730000
# 50%    492474.500000      25.280000      78.300000      23.750000
# 75%    611263.250000      29.700000      92.500000      29.080000
# max    730052.000000      42.900000     100.000000      42.020000
#
#            sht31_hum            co2           pm25             ws  \
# count  450766.000000  403452.000000  459271.000000  340671.000000
# mean       68.555058     717.431020      52.145192       3.673411
# std        34.324000     250.669267      28.282419       3.515722
# min         0.000000     103.517110       0.000000       0.000000
# 25%        58.000000     562.720000      33.000000       1.860000
# 50%        80.000000     704.180000      46.230000       3.050000
# 75%        97.000000     801.700000      65.660000       4.820000
# max       100.000000    4989.760000     249.000000      23.630000
#
#                   wd       pressure  solar  solar_cast  rainfall
# count  340698.000000  113622.000000    0.0         0.0       0.0
# mean      159.574767    4054.807647    NaN         NaN       NaN
# std        97.027697   17160.000592    NaN         NaN       NaN
# min         0.000000       0.000000    NaN         NaN       NaN
# 25%        89.000000     751.672700    NaN         NaN       NaN
# 50%       134.000000     930.603100    NaN         NaN       NaN
# 75%       247.000000     933.539175    NaN         NaN       NaN
# max       359.000000   93726.230000    NaN         NaN       NaN

# %%
df.isnull().sum()
# Out:
# id                  0
# created_at          0
# temperature      6973
# humidity         6891
# sht31_temp     123200
# sht31_hum       24390
# co2             71704
# pm25            15885
# ws             134485
# wd             134458
# pressure       361534
# solar          475156
# solar_cast     475156
# rainfall       475156
# dtype: int64

# %%
df['created_at'] = pd.to_datetime(df['created_at'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 475156 entries, 0 to 231925
# Data columns (total 14 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   id           475156 non-null  int64
#  1   created_at   475156 non-null  datetime64[ns]
#  2   temperature  468183 non-null  float64
#  3   humidity     468265 non-null  float64
#  4   sht31_temp   351956 non-null  float64
#  5   sht31_hum    450766 non-null  float64
#  6   co2          403452 non-null  float64
#  7   pm25         459271 non-null  float64
#  8   ws           340671 non-null  float64
#  9   wd           340698 non-null  float64
#  10  pressure     113622 non-null  float64
#  11  solar        0 non-null       float64
#  12  solar_cast   0 non-null       float64
#  13  rainfall     0 non-null       float64
# dtypes: datetime64[ns](1), float64(12), int64(1)
# memory usage: 54.4 MB

# %%
df['year'] = df['created_at'].dt.year
df.head()
# Out:
#        id          created_at  temperature  humidity  sht31_temp  sht31_hum  \
# 0  254867 2024-01-01 00:00:46         22.0      99.9         NaN       1.84
# 1  254868 2024-01-01 00:02:17         22.0      99.9         NaN       1.84
# 2  254871 2024-01-01 00:06:47         22.0      99.9         NaN       1.84
# 3  254872 2024-01-01 00:08:18         22.0      99.9         NaN       1.84
# 4  254875 2024-01-01 00:12:48         21.9      99.9         NaN       1.83
#
#           co2    pm25  ws  wd  pressure  solar  solar_cast  rainfall  year
# 0   934.14001  130.65 NaN NaN       NaN    NaN         NaN       NaN  2024
# 1   934.14001  130.65 NaN NaN       NaN    NaN         NaN       NaN  2024
# 2  1147.96997  130.65 NaN NaN       NaN    NaN         NaN       NaN  2024
# 3  1147.96997  130.65 NaN NaN       NaN    NaN         NaN       NaN  2024
# 4  1086.88000  130.65 NaN NaN       NaN    NaN         NaN       NaN  2024

# %%
nan_counts_by_year = df.groupby('year')[df.columns.drop('year')].apply(lambda x: x.isnull().sum())
print(nan_counts_by_year)
# Out:
#       id  created_at  temperature  humidity  sht31_temp  sht31_hum    co2  \
# year
# 2024   0           0         6915      6873      123159      24335  53711
# 2025   0           0           58        18          41         55  17993
#
#        pm25      ws      wd  pressure   solar  solar_cast  rainfall
# year
# 2024  15854  134444  134444    175149  243230      243230    243230
# 2025     31      41      14    186385  231926      231926    231926

# %%
df = df.drop(columns=['co2', 'ws', 'wd', 'pressure', 'solar', 'solar_cast', 'rainfall'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 475156 entries, 0 to 231925
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   id           475156 non-null  int64
#  1   created_at   475156 non-null  datetime64[ns]
#  2   temperature  468183 non-null  float64
#  3   humidity     468265 non-null  float64
#  4   sht31_temp   351956 non-null  float64
#  5   sht31_hum    450766 non-null  float64
#  6   pm25         459271 non-null  float64
#  7   year         475156 non-null  int32
# dtypes: datetime64[ns](1), float64(5), int32(1), int64(1)
# memory usage: 30.8 MB

# %%
df.head()
# Out:
#        id          created_at  temperature  humidity  sht31_temp  sht31_hum  \
# 0  254867 2024-01-01 00:00:46         22.0      99.9         NaN       1.84
# 1  254868 2024-01-01 00:02:17         22.0      99.9         NaN       1.84
# 2  254871 2024-01-01 00:06:47         22.0      99.9         NaN       1.84
# 3  254872 2024-01-01 00:08:18         22.0      99.9         NaN       1.84
# 4  254875 2024-01-01 00:12:48         21.9      99.9         NaN       1.83
#
#      pm25  year
# 0  130.65  2024
# 1  130.65  2024
# 2  130.65  2024
# 3  130.65  2024
# 4  130.65  2024

# %%
df.set_index('created_at', inplace=True, drop=True)
df.head()
# Out:
#                          id  temperature  humidity  sht31_temp  sht31_hum  \
# created_at
# 2024-01-01 00:00:46  254867         22.0      99.9         NaN       1.84
# 2024-01-01 00:02:17  254868         22.0      99.9         NaN       1.84
# 2024-01-01 00:06:47  254871         22.0      99.9         NaN       1.84
# 2024-01-01 00:08:18  254872         22.0      99.9         NaN       1.84
# 2024-01-01 00:12:48  254875         21.9      99.9         NaN       1.83
#
#                        pm25  year
# created_at
# 2024-01-01 00:00:46  130.65  2024
# 2024-01-01 00:02:17  130.65  2024
# 2024-01-01 00:06:47  130.65  2024
# 2024-01-01 00:08:18  130.65  2024
# 2024-01-01 00:12:48  130.65  2024

# %%
hourly_counts = df.resample('h').count()
hourly_means = df.resample('h').mean()

# Apply the condition: set mean to NaN if count < 23
for col in hourly_means.columns:
    hourly_means.loc[hourly_counts[col] < 23, col] = np.nan

# Round numerical columns to 2 decimal places (excluding 'year' which should be integer)
for col in hourly_means.columns:
    if pd.api.types.is_numeric_dtype(hourly_means[col]) and col != 'year':
        hourly_means[col] = hourly_means[col].round(2)

# Convert 'year' to integer, handling potential NaN values
if 'year' in hourly_means.columns:
    hourly_means['year'] = hourly_means['year'].apply(lambda x: int(x) if pd.notna(x) else x)

# Replace the 'id' column with a sequential series starting from 1
hourly_means['id'] = range(1, len(hourly_means) + 1)

# Reorder columns to ensure 'id' is the first column
current_cols = hourly_means.columns.tolist()
if 'id' in current_cols:
    current_cols.remove('id')
hourly_means = hourly_means[['id'] + current_cols]

# Display the first and last 5 rows
hourly_means.head(10)
# Out:
#                      id  temperature  humidity  sht31_temp  sht31_hum    pm25  \
# created_at
# 2024-01-01 00:00:00   1        21.78     99.90         NaN       1.83     NaN
# 2024-01-01 01:00:00   2        21.59     99.90         NaN       1.83     NaN
# 2024-01-01 02:00:00   3        21.44     99.90         NaN       1.82  132.09
# 2024-01-01 03:00:00   4        21.25     99.90         NaN       1.81  117.92
# 2024-01-01 04:00:00   5        21.12     99.90         NaN       1.81  114.37
# 2024-01-01 05:00:00   6        21.25     99.90         NaN       1.81   95.11
# 2024-01-01 06:00:00   7        23.03     99.90         NaN       1.82  125.77
# 2024-01-01 07:00:00   8        26.99     91.52         NaN       1.82  129.95
# 2024-01-01 08:00:00   9        32.47     71.83         NaN       1.81  140.50
# 2024-01-01 09:00:00  10        33.70     64.13         NaN       1.79  129.00
#
#                        year
# created_at
# 2024-01-01 00:00:00  2024.0
# 2024-01-01 01:00:00  2024.0
# 2024-01-01 02:00:00  2024.0
# 2024-01-01 03:00:00  2024.0
# 2024-01-01 04:00:00  2024.0
# 2024-01-01 05:00:00  2024.0
# 2024-01-01 06:00:00  2024.0
# 2024-01-01 07:00:00  2024.0
# 2024-01-01 08:00:00  2024.0
# 2024-01-01 09:00:00  2024.0

# %%
hourly_means['month'] = hourly_means.index.month

df_2024_hourly = hourly_means[hourly_means['year'] == 2024.0]
df_2025_hourly = hourly_means[hourly_means['year'] == 2025.0]

df_combined_hourly = pd.concat([df_2024_hourly, df_2025_hourly])

df_combined_hourly.head()
# Out:
#                      id  temperature  humidity  sht31_temp  sht31_hum    pm25  \
# created_at
# 2024-01-01 00:00:00   1        21.78      99.9         NaN       1.83     NaN
# 2024-01-01 01:00:00   2        21.59      99.9         NaN       1.83     NaN
# 2024-01-01 02:00:00   3        21.44      99.9         NaN       1.82  132.09
# 2024-01-01 03:00:00   4        21.25      99.9         NaN       1.81  117.92
# 2024-01-01 04:00:00   5        21.12      99.9         NaN       1.81  114.37
#
#                        year  month
# created_at
# 2024-01-01 00:00:00  2024.0      1
# 2024-01-01 01:00:00  2024.0      1
# 2024-01-01 02:00:00  2024.0      1
# 2024-01-01 03:00:00  2024.0      1
# 2024-01-01 04:00:00  2024.0      1

# %%
import calendar
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(14, 7))
sns.boxplot(x='month', y='pm25', hue='year', data=df_combined_hourly, palette='viridis')
plt.title('PM25 Levels Comparison: 2024 vs. 2025 (Outliers Cleaned)')
plt.xlabel('Month')
plt.ylabel('PM25 Level')
plt.xticks(ticks=range(12), labels=[calendar.month_abbr[i+1] for i in range(12)])
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend(title='Year')
plt.tight_layout()
plt.show()

# %%
import calendar
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(14, 7))
sns.boxplot(x='month', y='temperature', hue='year', data=df_combined_hourly, palette='viridis')
plt.title('Temperature Levels Comparison: 2024 vs. 2025 (Outliers Cleaned)')
plt.xlabel('Month')
plt.ylabel('Temperature Level')
plt.xticks(ticks=range(12), labels=[calendar.month_abbr[i+1] for i in range(12)])
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend(title='Year')
plt.tight_layout()
plt.show()

# %%
import calendar
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(14, 7))
sns.boxplot(x='month', y='humidity', hue='year', data=df_combined_hourly, palette='viridis')
plt.title('Humidity Levels Comparison: 2024 vs. 2025 (Outliers Cleaned)')
plt.xlabel('Month')
plt.ylabel('Humidity Level')
plt.xticks(ticks=range(12), labels=[calendar.month_abbr[i+1] for i in range(12)])
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend(title='Year')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Cleaning Outlier

# %%
import numpy as np

# Define target columns
target_columns = ['pm25', 'temperature', 'humidity']

# 1. Function to remove outliers using IQR
def remove_outliers(group):
    for col in target_columns:
        if col in group.columns and not group[col].isnull().all():
            Q1 = group[col].quantile(0.25)
            Q3 = group[col].quantile(0.75)
            IQR = Q3 - Q1
            lower_bound = Q1 - 1.5 * IQR
            upper_bound = Q3 + 1.5 * IQR
            # Set outliers to NaN
            group.loc[(group[col] < lower_bound) | (group[col] > upper_bound), col] = np.nan
    return group

# 2. Apply cleaning multiple times (5 passes) to reach absolute stability
for i in range(5):
    df_combined_hourly = df_combined_hourly.groupby(['year', 'month'], group_keys=False).apply(remove_outliers)

print("Data cleaning (5 passes) completed.")

# 3. Final Verification for visual consistency
sample_year, sample_month = 2024.0, 1
cleaned_sample_group = df_combined_hourly[(df_combined_hourly['year'] == sample_year) & (df_combined_hourly['month'] == sample_month)]

print(f"\n--- Final Outlier Check (Year: {int(sample_year)}, Month: {sample_month}) ---")
for col in target_columns:
    if not cleaned_sample_group[col].isnull().all():
        Q1, Q3 = cleaned_sample_group[col].quantile(0.25), cleaned_sample_group[col].quantile(0.75)
        IQR = Q3 - Q1
        lower, upper = Q1 - 1.5 * IQR, Q3 + 1.5 * IQR
        outliers = cleaned_sample_group[(cleaned_sample_group[col] < lower) | (cleaned_sample_group[col] > upper)]
        print(f"  {col}: {len(outliers)} outliers remaining in sample group.")
# Out:
# /tmp/ipython-input-474951471.py:21: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_combined_hourly = df_combined_hourly.groupby(['year', 'month'], group_keys=False).apply(remove_outliers)
# /tmp/ipython-input-474951471.py:21: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_combined_hourly = df_combined_hourly.groupby(['year', 'month'], group_keys=False).apply(remove_outliers)
# /tmp/ipython-input-474951471.py:21: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_combined_hourly = df_combined_hourly.groupby(['year', 'month'], group_keys=False).apply(remove_outliers)
# /tmp/ipython-input-474951471.py:21: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_combined_hourly = df_combined_hourly.groupby(['year', 'month'], group_keys=False).apply(remove_outliers)
# Data cleaning (5 passes) completed.
#
# --- Final Outlier Check (Year: 2024, Month: 1) ---
#   pm25: 0 outliers remaining in sample group.
#   temperature: 0 outliers remaining in sample group.
#   humidity: 0 outliers remaining in sample group.
# /tmp/ipython-input-474951471.py:21: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_combined_hourly = df_combined_hourly.groupby(['year', 'month'], group_keys=False).apply(remove_outliers)

# %%
# Set up the figure with subplots for each target column
fig, axes = plt.subplots(3, 1, figsize=(15, 18))
target_cols = ['pm25', 'temperature', 'humidity']
col_titles = ['PM25 (Cleaned)', 'Temperature (Cleaned)', 'Humidity (Cleaned)']

for i, col in enumerate(target_cols):
    sns.boxplot(ax=axes[i], x='month', y=col, hue='year', data=df_combined_hourly, palette='viridis')
    axes[i].set_title(f'{col_titles[i]} Levels Comparison: 2024 vs. 2025')
    axes[i].set_xlabel('Month')
    axes[i].set_ylabel(f'{col.capitalize()} Level')
    axes[i].set_xticks(range(12))
    axes[i].set_xticklabels([calendar.month_abbr[m+1] for m in range(12)])
    axes[i].grid(axis='y', linestyle='--', alpha=0.7)
    axes[i].legend(title='Year')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Analytic Data

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Filter data for January 1, 2024 from the hourly means
# We use df_combined_hourly here because it contains the original scale values (before normalization)
data_jan_1_2024 = df_combined_hourly.loc['2024-01-01']

# Create a bar chart for pm25 values
plt.figure(figsize=(12, 6))
sns.barplot(x=data_jan_1_2024.index.hour, y=data_jan_1_2024['pm25'], hue=data_jan_1_2024.index.hour, palette='viridis', legend=False)
plt.title('PM25 Levels on January 1, 2024 (Hourly Mean - Original Scale)')
plt.xlabel('Hour of Day')
plt.ylabel('PM25 Level')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
data_jan_1_2024 = hourly_means.loc['2024-01-01']

# Create a bar chart for humidity values
plt.figure(figsize=(12, 6))
sns.barplot(x=data_jan_1_2024.index.hour, y=data_jan_1_2024['humidity'], hue=data_jan_1_2024.index.hour, palette='viridis', legend=False)
plt.title('humidity Levels on January 1, 2024 (Hourly Mean)')
plt.xlabel('Hour of Day')
plt.ylabel('humidity Level')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
data_jan_1_2024 = hourly_means.loc['2024-01-01']

# Create a bar chart for temperature values
plt.figure(figsize=(12, 6))
sns.barplot(x=data_jan_1_2024.index.hour, y=data_jan_1_2024['temperature'], hue=data_jan_1_2024.index.hour, palette='viridis', legend=False)
plt.title('temperature Levels on January 1, 2024 (Hourly Mean)')
plt.xlabel('Hour of Day')
plt.ylabel('temperature Level')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Feature Engineering

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
columns_to_normalize = ['temperature', 'humidity', 'sht31_temp', 'sht31_hum', 'pm25']

scaler = MinMaxScaler()

# Melakukan normalisasi tanpa pembulatan untuk menjaga presisi data bagi model
hourly_means[columns_to_normalize] = scaler.fit_transform(hourly_means[columns_to_normalize])

# Menampilkan hasil dengan presisi tinggi (default)
hourly_means.head()
# Out:
#                      id  temperature  humidity  sht31_temp  sht31_hum  \
# created_at
# 2024-01-01 00:00:00   1     0.176796   0.99899         NaN     0.0183
# 2024-01-01 01:00:00   2     0.168721   0.99899         NaN     0.0183
# 2024-01-01 02:00:00   3     0.162346   0.99899         NaN     0.0182
# 2024-01-01 03:00:00   4     0.154271   0.99899         NaN     0.0181
# 2024-01-01 04:00:00   5     0.148746   0.99899         NaN     0.0181
#
#                          pm25    year  month
# created_at
# 2024-01-01 00:00:00       NaN  2024.0      1
# 2024-01-01 01:00:00       NaN  2024.0      1
# 2024-01-01 02:00:00  0.642649  2024.0      1
# 2024-01-01 03:00:00  0.573708  2024.0      1
# 2024-01-01 04:00:00  0.556437  2024.0      1

# %%
normalized_cols = ['temperature', 'humidity', 'pm25']
plt.figure(figsize=(12, 6))
sns.boxplot(data=hourly_means[normalized_cols], palette='Set2')
plt.title('Distribution of Normalized Features (Post-Normalization Check)')
plt.ylabel('Normalized Value (0-1)')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

display(hourly_means[normalized_cols].describe())
# Out:
#         temperature      humidity          pm25
# count  15105.000000  15108.000000  14911.000000
# mean       0.390020      0.751758      0.252123
# std        0.185393      0.189990      0.127453
# min        0.000000      0.000000      0.000000
# 25%        0.249894      0.619899      0.164445
# 50%        0.327667      0.779293      0.225893
# 75%        0.516787      0.915379      0.315583
# max        1.000000      1.000000      1.000000

# %%
correlation_df = hourly_means.drop(columns=['id', 'year', 'month','sht31_temp','sht31_hum']).copy()
correlation_matrix = correlation_df.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap of Normalized Hourly Environmental Data')
plt.show()

# %% [markdown]
# ### Final Data

# %%
print("Head of cleaned df_combined_hourly:")
display(df_combined_hourly.head())

print("\nTail of cleaned df_combined_hourly:")
display(df_combined_hourly.tail())
# Out:
# Head of cleaned df_combined_hourly:
#                      id  temperature  humidity  sht31_temp  sht31_hum    pm25  \
# created_at
# 2024-01-01 00:00:00   1        21.78      99.9         NaN       1.83     NaN
# 2024-01-01 01:00:00   2        21.59      99.9         NaN       1.83     NaN
# 2024-01-01 02:00:00   3        21.44      99.9         NaN       1.82  132.09
# 2024-01-01 03:00:00   4        21.25      99.9         NaN       1.81  117.92
# 2024-01-01 04:00:00   5        21.12      99.9         NaN       1.81  114.37
#
#                        year  month
# created_at
# 2024-01-01 00:00:00  2024.0      1
# 2024-01-01 01:00:00  2024.0      1
# 2024-01-01 02:00:00  2024.0      1
# 2024-01-01 03:00:00  2024.0      1
# 2024-01-01 04:00:00  2024.0      1
# Tail of cleaned df_combined_hourly:
#                         id  temperature  humidity  sht31_temp  sht31_hum  \
# created_at
# 2025-12-31 19:00:00  17540        24.28     81.53         0.0        0.0
# 2025-12-31 20:00:00  17541        24.20     83.17         0.0        0.0
# 2025-12-31 21:00:00  17542        23.88     85.90         0.0        0.0
# 2025-12-31 22:00:00  17543        23.93     84.83         0.0        0.0
# 2025-12-31 23:00:00  17544        23.55     85.73         0.0        0.0
#
#                        pm25    year  month
# created_at
# 2025-12-31 19:00:00   42.66  2025.0     12
# 2025-12-31 20:00:00   72.74  2025.0     12
# 2025-12-31 21:00:00     NaN  2025.0     12
# 2025-12-31 22:00:00  100.34  2025.0     12
# 2025-12-31 23:00:00     NaN  2025.0     12

# %%
target_columns = ['pm25', 'temperature', 'humidity']
null_counts_after_cleaning = df_combined_hourly[target_columns].isnull().sum()

print("Final Null Counts in Target Columns (After 5-pass IQR Cleaning):")
print(null_counts_after_cleaning)
# Out:
# Final Null Counts in Target Columns (After 5-pass IQR Cleaning):
# pm25           991
# temperature    559
# humidity       266
# dtype: int64

# %%
fig, axes = plt.subplots(3, 1, figsize=(15, 18))
target_cols = ['pm25', 'temperature', 'humidity']
col_titles = ['PM25 (Cleaned)', 'Temperature (Cleaned)', 'Humidity (Cleaned)']

for i, col in enumerate(target_cols):
    sns.boxplot(ax=axes[i], x='month', y=col, hue='year', data=df_combined_hourly, palette='viridis')
    axes[i].set_title(f'{col_titles[i]} Levels Comparison: 2024 vs. 2025')
    axes[i].set_xlabel('Month')
    axes[i].set_ylabel(f'{col.capitalize()} Level')
    axes[i].set_xticks(range(12))
    axes[i].set_xticklabels([calendar.month_abbr[m+1] for m in range(12)])
    axes[i].grid(axis='y', linestyle='--', alpha=0.7)
    axes[i].legend(title='Year')

plt.tight_layout()
plt.show()

# %%
# Select target columns for normalized statistics
target_cols = ['pm25', 'temperature', 'humidity']
stats_summary = hourly_means[target_cols].describe()

# Display the summary table
print("Descriptive Statistical Summary (Normalized Features):")
display(stats_summary)

# Verification of range
min_val = stats_summary.loc['min'].min()
max_val = stats_summary.loc['max'].max()

if min_val >= 0 and max_val <= 1:
    print(f"\nVerification Success: All normalized values are within the range [{min_val}, {max_val}], which is consistent with LSTM windowing requirements.")
else:
    print(f"\nVerification Warning: Data range [{min_val}, {max_val}] is outside the expected [0, 1] interval.")
# Out:
# Descriptive Statistical Summary (Normalized Features):
#                pm25   temperature      humidity
# count  14911.000000  15105.000000  15108.000000
# mean       0.252123      0.390020      0.751758
# std        0.127453      0.185393      0.189990
# min        0.000000      0.000000      0.000000
# 25%        0.164445      0.249894      0.619899
# 50%        0.225893      0.327667      0.779293
# 75%        0.315583      0.516787      0.915379
# max        1.000000      1.000000      1.000000
# Verification Success: All normalized values are within the range [0.0, 1.0], which is consistent with LSTM windowing requirements.

# %%
# Membuat dataset final untuk pelatihan model
data_training_GKU = df_combined_hourly.copy()

# Menampilkan informasi dataset baru
print("Dataset 'data_training_GKU' berhasil dibuat.")
print(f"Jumlah baris: {data_training_GKU.shape[0]}")
print(f"Jumlah kolom: {data_training_GKU.shape[1]}")
display(data_training_GKU.tail(5))
# Out:
# Dataset 'data_training_GKU' berhasil dibuat.
# Jumlah baris: 15338
# Jumlah kolom: 8
#                         id  temperature  humidity  sht31_temp  sht31_hum  \
# created_at
# 2025-12-31 19:00:00  17540        24.28     81.53         0.0        0.0
# 2025-12-31 20:00:00  17541        24.20     83.17         0.0        0.0
# 2025-12-31 21:00:00  17542        23.88     85.90         0.0        0.0
# 2025-12-31 22:00:00  17543        23.93     84.83         0.0        0.0
# 2025-12-31 23:00:00  17544        23.55     85.73         0.0        0.0
#
#                        pm25    year  month
# created_at
# 2025-12-31 19:00:00   42.66  2025.0     12
# 2025-12-31 20:00:00   72.74  2025.0     12
# 2025-12-31 21:00:00     NaN  2025.0     12
# 2025-12-31 22:00:00  100.34  2025.0     12
# 2025-12-31 23:00:00     NaN  2025.0     12

# %%
# Menyimpan dataset final ke file CSV
file_name = "data_training_GKU.csv"
data_training_GKU.to_csv(file_name, index=True)

print(f"Dataset berhasil disimpan dengan nama: {file_name}")
# Out:
# Dataset berhasil disimpan dengan nama: data_training_GKU.csv
